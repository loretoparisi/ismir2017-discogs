# %%
from preprocess_releases_xml_to_json import *
# Out:
# Dump file already found (/Volumes/Dataset/discogs/discogs_20180101_releases.xml.gz)
# Preprocessing data dump archive into json dump (/Volumes/Dataset/discogs/discogs_20180101_releases.json.dump)
# Processed 10000 releases
# Processed 20000 releases
# Processed 30000 releases
# ERROR: unexpected format for duration 711
# Processed 40000 releases
# Processed 50000 releases
# Processed 60000 releases
# Processed 70000 releases
# Processed 80000 releases
# Processed 90000 releases
# Processed 100000 releases
# Processed 110000 releases
# Processed 120000 releases
# Processed 130000 releases
# Processed 140000 releases
# Processed 150000 releases
# Processed 160000 releases
# Processed 170000 releases
# Processed 180000 releases
# Processed 190000 releases
# Processed 200000 releases
# Processed 210000 releases
# Processed 220000 releases
# Processed 230000 releases
# Processed 240000 releases
# Processed 250000 releases
# Processed 260000 releases
# Processed 270000 releases
# ...
